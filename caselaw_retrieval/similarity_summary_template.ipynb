# %%
import json
import os
import pandas as pd

path_data = "../data/caselaw_data/"

main_attributes = json.load(open(path_data + "2301.json", "rb"))

data = {key: [] for key in main_attributes}

for case in os.listdir(path_data):
    file = json.load(open(path_data + case, "rb"))
    for attribute in data.keys():
        data[attribute].append(file[attribute])
    
df = pd.DataFrame(data)
df.head()
# Out:
#                                                title  \
# 0                             VSRH, Kž eun 27/2017-4
# 1  Rechtbank Amsterdam, 11-06-2020, ECLI:NL:RBAMS...
# 2  Wyrok Sądu Najwyższego z dnia 4 lipca 2013 r. ...
# 3  Rechtbank Amsterdam, 14-09-2023, ECLI:NL:RBAMS...
# 4  Juzgado Central de Instrucción núm. 4. Auto 88...
#
#                                    court  \
# 0         Vrhovni sud Republike Hrvatske
# 1                    Rechtbank Amsterdam
# 2                         Sąd Najwyższy
# 3                    Rechtbank Amsterdam
# 4  Juzgado Central de Instrucción núm. 4
#
#                                        courtEng        dateOfDocument  \
# 0  The Supreme Court of the Republic of Croatia  2017-11-07T23:00:00Z
# 1                           Court of Amsterdam   2020-11-10T23:00:00Z
# 2                                 Supreme Court  2013-07-03T22:00:00Z
# 3                           Court of Amsterdam   2023-09-13T22:00:00Z
# 4                  Central Examining Court n. 4  2023-07-06T22:00:00Z
#
#                              jurisdiction  \
# 0      {'label': 'Croatia', 'code': 'HR'}
# 1  {'label': 'Netherlands', 'code': 'NL'}
# 2       {'label': 'Poland', 'code': 'PL'}
# 3  {'label': 'Netherlands', 'code': 'NL'}
# 4        {'label': 'Spain', 'code': 'ES'}
#
#                                             keywords  \
# 0  [content and form of European Arrest Warrant, ...
# 1              [FW Decision 2002/584 (EAW), assault]
# 2  [detention on remand, FW Decision 2002/584 (EAW)]
# 3              [Regulation 2018/1805, crime unknown]
# 4  [FW Decision 2002/584 (EAW), principle of mutu...
#
#                                              summary  \
# 0  <p class="ql-align-justify">Predmet se odnosi ...
# 1                                               None
# 2  <p>Stosowanie tymczasowego aresztowania w toku...
# 3
# 4  <p>El caso se refiere a los delitos de El caso...
#
#                                            summaryEn  \
# 0  <p class="ql-align-justify"><span style="color...
# 1  <p class="ql-align-justify"><em>The case conce...
# 2  <p>The application of detention on remand in t...
# 3  <p class="ql-align-justify"><em>The case conce...
# 4  <p>The case concerns the crimes of The case co...
#
#                               language                          decisionType  \
# 0  {'label': 'Croatian', 'code': 'HR'}  {'label': 'Other', 'code': 'Ruling'}
# 1     {'label': 'Dutch', 'code': 'NL'}    {'label': 'Judgment', 'code': 'J'}
# 2    {'label': 'Polish', 'code': 'PL'}    {'label': 'Judgment', 'code': 'J'}
# 3     {'label': 'Dutch', 'code': 'NL'}    {'label': 'Judgment', 'code': 'J'}
# 4   {'label': 'Spanish', 'code': 'ES'}       {'label': 'Order', 'code': 'O'}
#
#    ...                             nationalCaseLawRecords caseHistory  \
# 0  ...                                                 []          []
# 1  ...                                                 []          []
# 2  ...                                                 []          []
# 3  ...  [{'title': 'Rechtbank Amsterdam, 02-05-2023, E...          []
# 4  ...                                                 []          []
#
#   ecthrCaseLawRecords eurovoc facilexOntology nationalIdentifier  \
# 0                  []      []                   Kž eun 27/2017-4
# 1                  []      []                       13/751267-20
# 2                  []      []                       III KK 21/13
# 3                  []      []                          23/014471
# 4                  []      []                      AAN 7411/2023
#
#                               source  \
# 0
# 1
# 2             Supreme Court Database
# 3                     rechtspraak.nl
# 4  Centro de Documentación Judicial
#
#                                            sourceUrl  text  \
# 0  https://sudskapraksa.csp.vsrh.hr/decisionPdf?i...  None
# 1
# 2  http://www.sn.pl/orzecznictwo/SitePages/baza_o...
# 3  https://uitspraken.rechtspraak.nl/#!/details?i...
# 4  https://www.poderjudicial.es/search/AN/openDoc...
#
#                                          classifiers
# 0                                   [Content of EAW]
# 1  [Non-mandatory ground for refusal (double crim...
# 2                             [Detention conditions]
# 3  [Freezing, Transmission of a freezing/confisca...
# 4  [Double criminality, Non-mandatory ground for ...
#
# [5 rows x 24 columns]

# %%
df = df[df["jurisdiction"].apply(lambda x: x["label"]) == "Italy"]

# eval similarity based on whether two articles share a common eu provision - upgrade to similar article/paragraphs

relevant_cols = ["title", "summary", "summaryEn", "euCaselaw", "euProvisions", "eurovoc"]
df = df[relevant_cols]
df = df[(df["euProvisions"].str.len() > 0)] #  | (df["eurovoc"].str.len() > 0)
df = df.reset_index(drop = True)
df.head()
# Out:
#                                              title  \
# 0        Cass. Pen. sez. VI, 28/10/2022, no. 41102
# 1         Cass. Pen. sez F,  29/08/2023, n. 36397
# 2       Cass. Pen. sez. fer., 27/08/2020, n. 24593
# 3  Cassazione penale sez. VI, 30/10/2019, n. 49545
# 4          Cass. Pen. sez. VI, 15/09/2020, n.30885
#
#                                              summary  \
# 0  <p><span style="color: rgb(68, 68, 68);">In te...
# 1  <p><span style="color: rgb(0, 0, 0);">In tema ...
# 2  <p>L'art. 83, comma 12, L. n. 27 del 2020, pur...
# 3  <p>L'omessa trasmissione della traduzione in l...
# 4  <p>Meri vizi formali afferenti la comunicazion...
#
#                                            summaryEn euCaselaw  \
# 0  <p>The case is referred to the European arrest...        []
# 1  <p>The case concerns the crime of driving with...        []
# 2  <p>The case is referred to the European Arrest...        []
# 3  <p>Failure to provide an Italian-language tran...        []
# 4  <p>The case concerns the offences of illigal t...        []
#
#                                         euProvisions eurovoc
# 0  [{'celex': '32002F0584', 'name': '2002/584/JHA...      []
# 1  [{'celex': '32002F0584', 'name': '2002/584/JHA...      []
# 2  [{'celex': '32002F0584', 'name': '2002/584/JHA...      []
# 3  [{'celex': '32002F0584', 'name': '2002/584/JHA...      []
# 4  [{'celex': '32014L0041', 'name': 'Directive 20...      []

# %%
import re

# remove html elements
df["summaryEn"] = df["summaryEn"].apply(lambda x: re.sub(r"<.*?>", "", x))
df["summary"] = df["summary"].apply(lambda x: re.sub(r"<.*?>", "", x))
print(df.shape)
df.head()
# Out:
# (69, 6)
#                                              title  \
# 0        Cass. Pen. sez. VI, 28/10/2022, no. 41102
# 1         Cass. Pen. sez F,  29/08/2023, n. 36397
# 2       Cass. Pen. sez. fer., 27/08/2020, n. 24593
# 3  Cassazione penale sez. VI, 30/10/2019, n. 49545
# 4          Cass. Pen. sez. VI, 15/09/2020, n.30885
#
#                                              summary  \
# 0  In tema di mandato di arresto europeo, è onere...
# 1  In tema di mandato di arresto europeo, l'udien...
# 2  L'art. 83, comma 12, L. n. 27 del 2020, pur de...
# 3  L'omessa trasmissione della traduzione in ling...
# 4  Meri vizi formali afferenti la comunicazione n...
#
#                                            summaryEn euCaselaw  \
# 0  The case is referred to the European arrest wa...        []
# 1  The case concerns the crime of driving without...        []
# 2  The case is referred to the European Arrest Wa...        []
# 3  Failure to provide an Italian-language transla...        []
# 4  The case concerns the offences of illigal traf...        []
#
#                                         euProvisions eurovoc
# 0  [{'celex': '32002F0584', 'name': '2002/584/JHA...      []
# 1  [{'celex': '32002F0584', 'name': '2002/584/JHA...      []
# 2  [{'celex': '32002F0584', 'name': '2002/584/JHA...      []
# 3  [{'celex': '32002F0584', 'name': '2002/584/JHA...      []
# 4  [{'celex': '32014L0041', 'name': 'Directive 20...      []

# %%
with open("texts.txt", "w") as f:
    file_content = []

    for title, case in zip(df["title"], df["summaryEn"]):
        file_content += [title + "\n"]
        file_content += [case + "\n"]
        file_content += ["=======================\n"]

    f.writelines(file_content)

# %%
from sklearn.utils import shuffle

print(f"Cases that mention Italy/Italian: {len(df[df['summaryEn'].apply(lambda x: 'Ital' in x) == True])}")
print(f"Cases that mention ground(s): {len(df[df['summaryEn'].apply(lambda x: 'ground' in x.lower()) == True])}")
print(f"Cases that mention concern(s): {len(df[df['summaryEn'].apply(lambda x: 'concerns' in x.lower() or 'concern' in x.split(' ') or 'relevant' in x.split(' ')) == True])}")
print(f"Cases with all: {len(df[(df['summaryEn'].apply(lambda x: 'Ital' in x) == True)  & (df['summaryEn'].apply(lambda x: 'ground' in x.lower()) == True) & (df['summaryEn'].apply(lambda x: 'concerns' in x.lower() or 'concern' in x.split(' ') or 'relevant' in x.split(' ')) == True)])}")

df_temp = df[(df['summaryEn'].apply(lambda x: 'Ital' in x) == True)  & (df['summaryEn'].apply(lambda x: 'ground' in x.lower()) == True) & (df['summaryEn'].apply(lambda x: 'concerns' in x.lower() or 'concern' in x.split(' ') or 'relevant' in x.split(' ')) == True)]
df_nontemp = df[~((df['summaryEn'].apply(lambda x: 'Ital' in x) == True)  & (df['summaryEn'].apply(lambda x: 'ground' in x.lower()) == True) & (df['summaryEn'].apply(lambda x: 'concerns' in x.lower() or 'concern' in x.split(' ') or 'relevant' in x.split(' ')) == True))]

print(df_temp.shape, df_nontemp.shape)

df_nontemp = shuffle(df_nontemp, random_state = 42)

groups_non_temp = [df_nontemp.iloc[idx:idx + len(df_temp)] for idx in range(0,len(df_nontemp), len(df_temp))]

print(df_temp.shape, df_nontemp.shape)
# Out:
# Cases that mention Italy/Italian: 33
# Cases that mention ground(s): 20
# Cases that mention concern(s): 25
# Cases with all: 14
# (14, 6) (55, 6)
# (14, 6) (55, 6)

# %%
import matplotlib.pyplot as plt
import seaborn as sns

plt.figure(figsize = (16,9))
sns.histplot(df["summary"].str.split(" ").apply(lambda x: len(x)), bins = 15)
sns.despine()
plt.xlabel("Summary length (tokens)")
plt.ylabel("Frequency")
plt.title("Distribution of summary lengths in the Italian jurisdiction data")
plt.savefig("summary_length_IT.png", transparent = False)
plt.show()

# %%
import numpy as np

data_less150 = df[df["summary"].str.split(" ").apply(lambda x: len(x)) < np.median(df["summary"].str.split(" ").apply(lambda x: len(x)))]
data_more150 = df[df["summary"].str.split(" ").apply(lambda x: len(x)) >= np.median(df["summary"].str.split(" ").apply(lambda x: len(x)))]

print(np.median(df["summary"].str.split(" ").apply(lambda x: len(x))))
# Out:
# 96.0

# %%
print(data_less150.shape, data_more150.shape)
# Out:
# (34, 6) (35, 6)

# %%
import numpy as np
import torch

from sentence_transformers import SentenceTransformer

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(device)
# Out:
# cuda

# %% [markdown]
# $P=\frac{relevant\ retrieved\ docs}{total\ retrieved\ docs}$
#
# $R=\frac{relevant\ retrieved\ docs}{total\ retrieved\ docs\ in\ dataset}$
#
# $MRR=\frac{1}{|Q|}\sum_q^Q \frac{1}{rank_q}$ where
#
# $MRR^*=\frac{1}{|Q|}\sum_q^Q \frac{1}{rank_q + missed}$ where
#
# $rank_q = 0$ if there are no relevant documents in the retrieved search window\
# where $missed$ is the number of relevant documents missed in the retrieved search window equal to at most the number non-relevant retrieved documents
#
# $DCG=\sum_{i=1}^p\frac{rel_i}{log_2(i+1)}$

# %%
def get_citation_to_eu_instrument(item):
    return item["celex"] + "." + ".".join([mention["value"] for mention in item["itemsBase"] if mention["value"] != ""])

# %%
from sklearn.metrics.pairwise import cosine_similarity

# at least one shared EU provision ==> similar
# at least one shared EuroVoc ==> similar
# eval - score each of the 5 retrieved cases for shared celex codes (only one celex now)

def cosine_search(query, search, query_type, top_k = 5):
    cosine_scores = cosine_similarity(query, search)
    score_doc = []

    denesting_label = ""
    if query_type == "euProvisions":
        denesting_label = "celex"
    elif query_type == "eurovoc":
        denesting_label = "label"
    elif query_type == "citation":
        denesting_label = None
        query_type = "euProvisions"

    running_mrr = 0
    running_mrr_normal = 0
    metrics = {}

    for i in range(cosine_scores.shape[0]):
        all_matches = np.argsort(cosine_scores[i])[::-1]
        best_matches = all_matches[1:top_k+1]
        
        if denesting_label:
            query_celex = df.iloc[i][query_type][0][denesting_label]
        else:
            query_celex = get_citation_to_eu_instrument(df.iloc[i][query_type][0])

        # see which top_k retrieved documents were retrieved
        score = []
        for retrieved_case in best_matches:
            if denesting_label:
                retrieved_celex = [provision[denesting_label] for provision in df.iloc[retrieved_case][query_type]]
            else:
                retrieved_celex = [get_citation_to_eu_instrument(provision) for provision in df.iloc[retrieved_case][query_type]]
            score.append(int(query_celex in retrieved_celex))

        ### find all relevant cases that were missed
        missed_matches = []
        # for retrieved_case in all_matches[1:len(df_temp)]:
        for retrieved_case in all_matches[1:]:
            if denesting_label:
                retrieved_celex = [provision[denesting_label] for provision in df.iloc[retrieved_case][query_type]]
            else:
                retrieved_celex = [get_citation_to_eu_instrument(provision) for provision in df.iloc[retrieved_case][query_type]]
            missed_matches.append(int(query_celex in retrieved_celex))

        score = np.asarray(score)
        no_missed_matches = np.sum(missed_matches) if np.sum(missed_matches) > 0 else 1
        score_doc.append([np.sum(score)/top_k, np.sum(score)/no_missed_matches])
        rank = np.where(score != 0)[0] # get first non-zero rank
        rank = (rank[0] + 1) if len(rank) > 0 else 0
        missed = np.min([len(np.where(score == 0)[0]), np.sum(missed_matches)])
        running_mrr += 1/(rank + missed) if rank != 0 else 0 # rank starts at 0 bcs. of this so rank + 1
        running_mrr_normal += 1/(rank) if rank != 0 else 0 # rank starts at 0 bcs. of this so rank + 1
        print(f"Query score: {score}, rank of 1st relevant case: {rank}, mrr_w_penalty: {running_mrr:0.3f}, mrr: {running_mrr_normal:0.3f}, number of cases still missing in the query {missed}, total missed: {np.sum(missed_matches)}")
        
    # macro precision@k and recall@k
    precision, recall = np.mean(score_doc, 0)
    f1 = 2 * precision * recall / (precision + recall)

    metrics["precision"] = precision
    metrics["recall"] = recall
    metrics["f1"] = f1
    metrics["mrr_miss"] = running_mrr/cosine_scores.shape[0]
    metrics["mrr"] = running_mrr_normal/cosine_scores.shape[0]
    
    return metrics

# %% [markdown]
# Query score: [1 1 1 1 1], rank of 1st relevant case: 1, mrr_w_penalty: 57.779, mrr: 62.833, number of cases still missing in the query 0, total missed: 10
#
# Query score: [1 0 0 0 0], rank of 1st relevant case: 1, mrr_w_penalty: 58.029, mrr: 63.833, number of cases still missing in the query 3, total missed: 3

# %%
# optimal_top_k = 25 (debatable) 

from collections import defaultdict
from functools import partial
from tqdm import tqdm

models = ["distiluse-base-multilingual-cased-v2", "paraphrase-multilingual-mpnet-base-v2"]
# search_functions = [partial(cosine_search, query_type = "euProvisions"), partial(cosine_search, query_type = "eurovoc"), cosine_search_both]
search_functions = [partial(cosine_search, query_type = "citation")]

scores_search_function = defaultdict()

sl, tl = "EN", "IT"

d = df

for search_func in tqdm(search_functions):
    scores = {"Model": [], "Pair": [], "Value": [], "Score": []}

    for model_name in models:
        model = SentenceTransformer("../models/" + model_name).to(device)

        data_pairs = [
            (f"{sl}-{sl}", np.asarray(d["summaryEn"].apply(model.encode).tolist()), np.asarray(d["summaryEn"].apply(model.encode).tolist())),
            (f"{tl}-{tl}", np.asarray(d["summary"].apply(model.encode).tolist()), np.asarray(d["summary"].apply(model.encode).tolist())),
            (f"{sl}-{tl}", np.asarray(d["summaryEn"].apply(model.encode).tolist()), np.asarray(d["summary"].apply(model.encode).tolist())),
            (f"{tl}-{sl}", np.asarray(d["summary"].apply(model.encode).tolist()), np.asarray(d["summaryEn"].apply(model.encode).tolist()))
        ]

        for (pair, query, search) in data_pairs:
            metrics = search_func(query = query, search = search, top_k = 5)

            scores["Model"] += [model_name] * len(list(metrics.keys()))
            scores["Pair"] += [pair] * len(list(metrics.keys()))
            scores["Value"] += list(metrics.values())
            scores["Score"] += list(metrics.keys())

    name = ""
    if type(search_func) == partial:
        name = search_func.func.__name__ + "_" + "_".join(list(search_func.keywords.values()))
    else:
        name = search_func.__name__
    scores_search_function[name] = scores
# Out:
#   0%|          | 0/1 [00:00<?, ?it/s]
# Query score: [1 0 0 0 0], rank of 1st relevant case: 1, mrr_w_penalty: 0.500, mrr: 1.000, number of cases still missing in the query 1, total missed: 1
# Query score: [0 0 0 0 0], rank of 1st relevant case: 0, mrr_w_penalty: 0.500, mrr: 1.000, number of cases still missing in the query 2, total missed: 2
# Query score: [0 0 0 0 0], rank of 1st relevant case: 0, mrr_w_penalty: 0.500, mrr: 1.000, number of cases still missing in the query 0, total missed: 0
# Query score: [0 0 0 0 0], rank of 1st relevant case: 0, mrr_w_penalty: 0.500, mrr: 1.000, number of cases still missing in the query 0, total missed: 0
# Query score: [0 0 0 1 0], rank of 1st relevant case: 4, mrr_w_penalty: 0.625, mrr: 1.250, number of cases still missing in the query 4, total missed: 6
# Query score: [0 0 0 0 0], rank of 1st relevant case: 0, mrr_w_penalty: 0.625, mrr: 1.250, number of cases still missing in the query 0, total missed: 0
# Query score: [0 0 0 0 0], rank of 1st relevant case: 0, mrr_w_penalty: 0.625, mrr: 1.250, number of cases still missing in the query 5, total missed: 5
# Query score: [1 0 0 0 0], rank of 1st relevant case: 1, mrr_w_penalty: 0.825, mrr: 2.250, number of cases still missing in the query 4, total missed: 10
# Query score: [1 1 0 0 1], rank of 1st relevant case: 1, mrr_w_penalty: 1.158, mrr: 3.250, number of cases still missing in the query 2, total missed: 10
# Query score: [0 0 0 0 0], rank of 1st relevant case: 0, mrr_w_penalty: 1.158, mrr: 3.250, number of cases still missing in the query 2, total missed: 2
# Query score: [0 0 0 0 0], rank of 1st relevant case: 0, mrr_w_penalty: 1.158, mrr: 3.250, number of cases still missing in the query 5, total missed: 5
# Query score: [1 0 1 1 1], rank of 1st relevant case: 1, mrr_w_penalty: 1.658, mrr: 4.250, number of cases still missing in the query 1, total missed: 9
# Query score: [0 0 0 1 1], rank of 1st relevant case: 4, mrr_w_penalty: 1.801, mrr: 4.500, number of cases still missing in the query 3, total missed: 9
# Query score: [0 0 0 0 0], rank of 1st relevant case: 0, mrr_w_penalty: 1.801, mrr: 4.500, number of cases still missing in the query 5, total missed: 5
# Query score: [1 1 0 0 0], rank of 1st relevant case: 1, mrr_w_penalty: 2.051, mrr: 5.500, number of cases still missing in the query 3, total missed: 10
# Query score: [1 0 1 1 1], rank of 1st relevant case: 1, mrr_w_penalty: 2.551, mrr: 6.500, number of cases still missing in the query 1, total missed: 9
# Query score: [0 1 0 1 1], rank of 1st relevant case: 2, mrr_w_penalty: 2.801, mrr: 7.000, number of cases still missing in the query 2, total missed: 9
# Query score: [0 1 1 0 0], rank of 1st relevant case: 2, mrr_w_penalty: 3.001, mrr: 7.500, number of cases still missing in the query 3, total missed: 5
# Query score: [0 0 1 1 0], rank of 1st relevant case: 3, mrr_w_penalty: 3.168, mrr: 7.833, number of cases still missing in the query 3, total missed: 9
# Query score: [1 0 0 0 0], rank of 1st relevant case: 1, mrr_w_penalty: 3.368, mrr: 8.833, number of cases still missing in the query 4, total missed: 10
# Query score: [1 0 1 0 1], rank of 1st relevant case: 1, mrr_w_penalty: 3.701, mrr: 9.833, number of cases still missing in the query 2, total missed: 9
# Query score: [1 0 0 0 0], rank of 1st relevant case: 1, mrr_w_penalty: 4.201, mrr: 10.833, number of cases still missing in the query 1, total missed: 1
# Query score: [0 0 0 0 0], rank of 1st relevant case: 0, mrr_w_penalty: 4.201, mrr: 10.833, number of cases still missing in the query 0, total missed: 0
# Query score: [1 0 0 0 0], rank of 1st relevant case: 1, mrr_w_penalty: 4.701, mrr: 11.833, number of cases still missing in the query 1, total missed: 1
# Query score: [1 0 0 0 0], rank of 1st relevant case: 1, mrr_w_penalty: 4.901, mrr: 12.833, number of cases still missing in the query 4, total missed: 10
# Query score: [0 0 0 0 0], rank of 1st relevant case: 0, mrr_w_penalty: 4.901, mrr: 12.833, number of cases still missing in the query 5, total missed: 9
# Query score: [0 0 0 0 0], rank of 1st relevant case: 0, mrr_w_penalty: 4.901, mrr: 12.833, number of cases still missing in the query 0, total missed: 0
# Query score: [0 0 0 0 0], rank of 1st relevant case: 0, mrr_w_penalty: 4.901, mrr: 12.833, number of cases still missing in the query 5, total missed: 10
# Query score: [1 0 0 0 0], rank of 1st relevant case: 1, mrr_w_penalty: 5.401, mrr: 13.833, number of cases still missing in the query 1, total missed: 1
# Query score: [0 1 0 0 0], rank of 1st relevant case: 2, mrr_w_penalty: 5.568, mrr: 14.333, number of cases still missing in the query 4, total missed: 5
# Query score: [0 1 0 0 0], rank of 1st relevant case: 2, mrr_w_penalty: 5.735, mrr: 14.833, number of cases still missing in the query 4, total missed: 10
# Query score: [0 1 1 1 0], rank of 1st relevant case: 2, mrr_w_penalty: 5.985, mrr: 15.333, number of cases still missing in the query 2, total missed: 6
# Query score: [0 1 0 0 0], rank of 1st relevant case: 2, mrr_w_penalty: 6.185, mrr: 15.833, number of cases still missing in the query 3, total missed: 3
# Query score: [0 1 0 0 0], rank of 1st relevant case: 2, mrr_w_penalty: 6.351, mrr: 16.333, number of cases still missing in the query 4, total missed: 10
# Query score: [1 0 0 0 0], rank of 1st relevant case: 1, mrr_w_penalty: 6.851, mrr: 17.333, number of cases still missing in the query 1, total missed: 1
# Query score: [0 1 0 0 0], rank of 1st relevant case: 2, mrr_w_penalty: 7.185, mrr: 17.833, number of cases still missing in the query 1, total missed: 1
# Query score: [0 0 0 0 0], rank of 1st relevant case: 0, mrr_w_penalty: 7.185, mrr: 17.833, number of cases still missing in the query 5, total missed: 10
# Query score: [1 0 0 0 0], rank of 1st relevant case: 1, mrr_w_penalty: 7.385, mrr: 18.833, number of cases still missing in the query 4, total missed: 10
# Query score: [0 0 0 0 0], rank of 1st relevant case: 0, mrr_w_penalty: 7.385, mrr: 18.833, number of cases still missing in the query 0, total missed: 0
# Query score: [1 1 0 1 0], rank of 1st relevant case: 1, mrr_w_penalty: 7.718, mrr: 19.833, number of cases still missing in the query 2, total missed: 6
# Query score: [0 0 0 0 1], rank of 1st relevant case: 5, mrr_w_penalty: 7.843, mrr: 20.033, number of cases still missing in the query 3, total missed: 3
# Query score: [0 0 0 0 0], rank of 1st relevant case: 0, mrr_w_penalty: 7.843, mrr: 20.033, number of cases still missing in the query 0, total missed: 0
# Query score: [0 0 0 0 0], rank of 1st relevant case: 0, mrr_w_penalty: 7.843, mrr: 20.033, number of cases still missing in the query 5, total missed: 5
# Query score: [1 0 0 0 0], rank of 1st relevant case: 1, mrr_w_penalty: 8.093, mrr: 21.033, number of cases still missing in the query 3, total missed: 3
# Query score: [0 0 0 0 0], rank of 1st relevant case: 0, mrr_w_penalty: 8.093, mrr: 21.033, number of cases still missing in the query 5, total missed: 6
# Query score: [0 0 0 0 0], rank of 1st relevant case: 0, mrr_w_penalty: 8.093, mrr: 21.033, number of cases still missing in the query 5, total missed: 6
# Query score: [0 0 0 0 0], rank of 1st relevant case: 0, mrr_w_penalty: 8.093, mrr: 21.033, number of cases still missing in the query 1, total missed: 1
# Query score: [0 0 0 0 0], rank of 1st relevant case: 0, mrr_w_penalty: 8.093, mrr: 21.033, number of cases still missing in the query 0, total missed: 0
# Query score: [1 0 0 1 0], rank of 1st relevant case: 1, mrr_w_penalty: 8.343, mrr: 22.033, number of cases still missing in the query 3, total missed: 9
# Query score: [1 0 0 0 0], rank of 1st relevant case: 1, mrr_w_penalty: 8.843, mrr: 23.033, number of cases still missing in the query 1, total missed: 1
# Query score: [1 1 0 0 0], rank of 1st relevant case: 1, mrr_w_penalty: 9.093, mrr: 24.033, number of cases still missing in the query 3, total missed: 10
# Query score: [0 0 0 1 0], rank of 1st relevant case: 4, mrr_w_penalty: 9.236, mrr: 24.283, number of cases still missing in the query 3, total missed: 3
# Query score: [1 1 0 0 1], rank of 1st relevant case: 1, mrr_w_penalty: 9.569, mrr: 25.283, number of cases still missing in the query 2, total missed: 9
# Query score: [0 0 1 0 0], rank of 1st relevant case: 3, mrr_w_penalty: 9.736, mrr: 25.617, number of cases still missing in the query 3, total missed: 3
# Query score: [1 0 0 0 0], rank of 1st relevant case: 1, mrr_w_penalty: 10.236, mrr: 26.617, number of cases still missing in the query 1, total missed: 1
# Query score: [0 0 0 0 0], rank of 1st relevant case: 0, mrr_w_penalty: 10.236, mrr: 26.617, number of cases still missing in the query 0, total missed: 0
# Query score: [0 0 0 0 0], rank of 1st relevant case: 0, mrr_w_penalty: 10.236, mrr: 26.617, number of cases still missing in the query 0, total missed: 0
# Query score: [0 0 1 0 0], rank of 1st relevant case: 3, mrr_w_penalty: 10.402, mrr: 26.950, number of cases still missing in the query 3, total missed: 3
# Query score: [1 0 0 0 0], rank of 1st relevant case: 1, mrr_w_penalty: 10.902, mrr: 27.950, number of cases still missing in the query 1, total missed: 1
# Query score: [1 1 1 1 0], rank of 1st relevant case: 1, mrr_w_penalty: 11.402, mrr: 28.950, number of cases still missing in the query 1, total missed: 9
# Query score: [1 0 0 0 0], rank of 1st relevant case: 1, mrr_w_penalty: 11.902, mrr: 29.950, number of cases still missing in the query 1, total missed: 1
# Query score: [0 0 0 0 0], rank of 1st relevant case: 0, mrr_w_penalty: 11.902, mrr: 29.950, number of cases still missing in the query 3, total missed: 3
# Query score: [0 0 0 0 0], rank of 1st relevant case: 0, mrr_w_penalty: 11.902, mrr: 29.950, number of cases still missing in the query 3, total missed: 3
# Query score: [0 0 0 0 0], rank of 1st relevant case: 0, mrr_w_penalty: 11.902, mrr: 29.950, number of cases still missing in the query 0, total missed: 0
# Query score: [0 0 0 0 0], rank of 1st relevant case: 0, mrr_w_penalty: 11.902, mrr: 29.950, number of cases still missing in the query 0, total missed: 0
# Query score: [0 0 0 0 0], rank of 1st relevant case: 0, mrr_w_penalty: 11.902, mrr: 29.950, number of cases still missing in the query 2, total missed: 2
# Query score: [1 1 1 0 0], rank of 1st relevant case: 1, mrr_w_penalty: 12.236, mrr: 30.950, number of cases still missing in the query 2, total missed: 6
# Query score: [0 0 0 0 0], rank of 1st relevant case: 0, mrr_w_penalty: 12.236, mrr: 30.950, number of cases still missing in the query 0, total missed: 0
# Query score: [1 1 0 0 1], rank of 1st relevant case: 1, mrr_w_penalty: 12.569, mrr: 31.950, number of cases still missing in the query 2, total missed: 6
# Query score: [1 0 0 0 0], rank of 1st relevant case: 1, mrr_w_penalty: 0.500, mrr: 1.000, number of cases still missing in the query 1, total missed: 1
# Query score: [0 0 0 0 0], rank of 1st relevant case: 0, mrr_w_penalty: 0.500, mrr: 1.000, number of cases still missing in the query 2, total missed: 2
# Query score: [0 0 0 0 0], rank of 1st relevant case: 0, mrr_w_penalty: 0.500, mrr: 1.000, number of cases still missing in the query 0, total missed: 0
# Query score: [0 0 0 0 0], rank of 1st relevant case: 0, mrr_w_penalty: 0.500, mrr: 1.000, number of cases still missing in the query 0, total missed: 0
# Query score: [0 0 0 0 0], rank of 1st relevant case: 0, mrr_w_penalty: 0.500, mrr: 1.000, number of cases still missing in the query 5, total missed: 6
# Query score: [0 0 0 0 0], rank of 1st relevant case: 0, mrr_w_penalty: 0.500, mrr: 1.000, number of cases still missing in the query 0, total missed: 0
# Query score: [0 0 0 0 0], rank of 1st relevant case: 0, mrr_w_penalty: 0.500, mrr: 1.000, number of cases still missing in the query 5, total missed: 5
# Query score: [0 0 0 0 0], rank of 1st relevant case: 0, mrr_w_penalty: 0.500, mrr: 1.000, number of cases still missing in the query 5, total missed: 10
# Query score: [1 1 1 0 0], rank of 1st relevant case: 1, mrr_w_penalty: 0.833, mrr: 2.000, number of cases still missing in the query 2, total missed: 10
# Query score: [0 0 0 0 0], rank of 1st relevant case: 0, mrr_w_penalty: 0.833, mrr: 2.000, number of cases still missing in the query 2, total missed: 2
# Query score: [0 0 0 0 0], rank of 1st relevant case: 0, mrr_w_penalty: 0.833, mrr: 2.000, number of cases still missing in the query 5, total missed: 5
# Query score: [1 0 1 1 0], rank of 1st relevant case: 1, mrr_w_penalty: 1.167, mrr: 3.000, number of cases still missing in the query 2, total missed: 9
# Query score: [0 1 0 0 0], rank of 1st relevant case: 2, mrr_w_penalty: 1.333, mrr: 3.500, number of cases still missing in the query 4, total missed: 9
# Query score: [0 0 0 0 0], rank of 1st relevant case: 0, mrr_w_penalty: 1.333, mrr: 3.500, number of cases still missing in the query 5, total missed: 5
# Query score: [1 1 0 1 1], rank of 1st relevant case: 1, mrr_w_penalty: 1.833, mrr: 4.500, number of cases still missing in the query 1, total missed: 10
# Query score: [1 1 1 1 0], rank of 1st relevant case: 1, mrr_w_penalty: 2.333, mrr: 5.500, number of cases still missing in the query 1, total missed: 9
# Query score: [0 1 0 0 0], rank of 1st relevant case: 2, mrr_w_penalty: 2.500, mrr: 6.000, number of cases still missing in the query 4, total missed: 9
# Query score: [0 0 0 0 0], rank of 1st relevant case: 0, mrr_w_penalty: 2.500, mrr: 6.000, number of cases still missing in the query 5, total missed: 5
# Query score: [1 0 0 1 0], rank of 1st relevant case: 1, mrr_w_penalty: 2.750, mrr: 7.000, number of cases still missing in the query 3, total missed: 9
# Query score: [1 0 0 0 0], rank of 1st relevant case: 1, mrr_w_penalty: 2.950, mrr: 8.000, number of cases still missing in the query 4, total missed: 10
# Query score: [1 0 1 1 0], rank of 1st relevant case: 1, mrr_w_penalty: 3.283, mrr: 9.000, number of cases still missing in the query 2, total missed: 9
# Query score: [0 1 0 0 0], rank of 1st relevant case: 2, mrr_w_penalty: 3.617, mrr: 9.500, number of cases still missing in the query 1, total missed: 1
# Query score: [0 0 0 0 0], rank of 1st relevant case: 0, mrr_w_penalty: 3.617, mrr: 9.500, number of cases still missing in the query 0, total missed: 0
# Query score: [0 0 0 0 1], rank of 1st relevant case: 5, mrr_w_penalty: 3.783, mrr: 9.700, number of cases still missing in the query 1, total missed: 1
# Query score: [0 0 0 1 0], rank of 1st relevant case: 4, mrr_w_penalty: 3.908, mrr: 9.950, number of cases still missing in the query 4, total missed: 10
# Query score: [0 0 0 1 0], rank of 1st relevant case: 4, mrr_w_penalty: 4.033, mrr: 10.200, number of cases still missing in the query 4, total missed: 9
# Query score: [0 0 0 0 0], rank of 1st relevant case: 0, mrr_w_penalty: 4.033, mrr: 10.200, number of cases still missing in the query 0, total missed: 0
# Query score: [0 0 0 0 0], rank of 1st relevant case: 0, mrr_w_penalty: 4.033, mrr: 10.200, number of cases still missing in the query 5, total missed: 10
# Query score: [0 0 0 0 0], rank of 1st relevant case: 0, mrr_w_penalty: 4.033, mrr: 10.200, number of cases still missing in the query 1, total missed: 1
# Query score: [0 0 0 0 0], rank of 1st relevant case: 0, mrr_w_penalty: 4.033, mrr: 10.200, number of cases still missing in the query 5, total missed: 5
# Query score: [0 0 1 0 0], rank of 1st relevant case: 3, mrr_w_penalty: 4.176, mrr: 10.533, number of cases still missing in the query 4, total missed: 10
# Query score: [1 0 1 1 0], rank of 1st relevant case: 1, mrr_w_penalty: 4.510, mrr: 11.533, number of cases still missing in the query 2, total missed: 6
# Query score: [0 1 0 0 0], rank of 1st relevant case: 2, mrr_w_penalty: 4.710, mrr: 12.033, number of cases still missing in the query 3, total missed: 3
# Query score: [0 0 0 0 0], rank of 1st relevant case: 0, mrr_w_penalty: 4.710, mrr: 12.033, number of cases still missing in the query 5, total missed: 10
# Query score: [1 0 0 0 0], rank of 1st relevant case: 1, mrr_w_penalty: 5.210, mrr: 13.033, number of cases still missing in the query 1, total missed: 1
# Query score: [0 0 1 0 0], rank of 1st relevant case: 3, mrr_w_penalty: 5.460, mrr: 13.367, number of cases still missing in the query 1, total missed: 1
# Query score: [0 0 0 0 0], rank of 1st relevant case: 0, mrr_w_penalty: 5.460, mrr: 13.367, number of cases still missing in the query 5, total missed: 10
# Query score: [1 0 0 0 0], rank of 1st relevant case: 1, mrr_w_penalty: 5.660, mrr: 14.367, number of cases still missing in the query 4, total missed: 10
# Query score: [0 0 0 0 0], rank of 1st relevant case: 0, mrr_w_penalty: 5.660, mrr: 14.367, number of cases still missing in the query 0, total missed: 0
# Query score: [1 0 1 1 0], rank of 1st relevant case: 1, mrr_w_penalty: 5.993, mrr: 15.367, number of cases still missing in the query 2, total missed: 6
# Query score: [0 0 0 0 0], rank of 1st relevant case: 0, mrr_w_penalty: 5.993, mrr: 15.367, number of cases still missing in the query 3, total missed: 3
# Query score: [0 0 0 0 0], rank of 1st relevant case: 0, mrr_w_penalty: 5.993, mrr: 15.367, number of cases still missing in the query 0, total missed: 0
# Query score: [0 0 0 0 0], rank of 1st relevant case: 0, mrr_w_penalty: 5.993, mrr: 15.367, number of cases still missing in the query 5, total missed: 5
# Query score: [0 1 0 0 0], rank of 1st relevant case: 2, mrr_w_penalty: 6.193, mrr: 15.867, number of cases still missing in the query 3, total missed: 3
# Query score: [0 0 0 0 0], rank of 1st relevant case: 0, mrr_w_penalty: 6.193, mrr: 15.867, number of cases still missing in the query 5, total missed: 6
# Query score: [0 0 0 0 0], rank of 1st relevant case: 0, mrr_w_penalty: 6.193, mrr: 15.867, number of cases still missing in the query 5, total missed: 6
# Query score: [0 0 0 0 0], rank of 1st relevant case: 0, mrr_w_penalty: 6.193, mrr: 15.867, number of cases still missing in the query 1, total missed: 1
# Query score: [0 0 0 0 0], rank of 1st relevant case: 0, mrr_w_penalty: 6.193, mrr: 15.867, number of cases still missing in the query 0, total missed: 0
# Query score: [0 0 0 0 0], rank of 1st relevant case: 0, mrr_w_penalty: 6.193, mrr: 15.867, number of cases still missing in the query 5, total missed: 9
# Query score: [1 0 0 0 0], rank of 1st relevant case: 1, mrr_w_penalty: 6.693, mrr: 16.867, number of cases still missing in the query 1, total missed: 1
# Query score: [1 1 0 1 1], rank of 1st relevant case: 1, mrr_w_penalty: 7.193, mrr: 17.867, number of cases still missing in the query 1, total missed: 10
# Query score: [0 1 0 0 1], rank of 1st relevant case: 2, mrr_w_penalty: 7.393, mrr: 18.367, number of cases still missing in the query 3, total missed: 3
# Query score: [1 1 1 0 0], rank of 1st relevant case: 1, mrr_w_penalty: 7.726, mrr: 19.367, number of cases still missing in the query 2, total missed: 9
# Query score: [0 0 0 1 0], rank of 1st relevant case: 4, mrr_w_penalty: 7.869, mrr: 19.617, number of cases still missing in the query 3, total missed: 3
# Query score: [1 0 0 0 0], rank of 1st relevant case: 1, mrr_w_penalty: 8.369, mrr: 20.617, number of cases still missing in the query 1, total missed: 1
# Query score: [0 0 0 0 0], rank of 1st relevant case: 0, mrr_w_penalty: 8.369, mrr: 20.617, number of cases still missing in the query 0, total missed: 0
# Query score: [0 0 0 0 0], rank of 1st relevant case: 0, mrr_w_penalty: 8.369, mrr: 20.617, number of cases still missing in the query 0, total missed: 0
# Query score: [1 0 0 0 0], rank of 1st relevant case: 1, mrr_w_penalty: 8.619, mrr: 21.617, number of cases still missing in the query 3, total missed: 3
# Query score: [0 1 0 0 0], rank of 1st relevant case: 2, mrr_w_penalty: 8.952, mrr: 22.117, number of cases still missing in the query 1, total missed: 1
# Query score: [1 1 1 0 0], rank of 1st relevant case: 1, mrr_w_penalty: 9.286, mrr: 23.117, number of cases still missing in the query 2, total missed: 9
# Query score: [0 0 1 0 0], rank of 1st relevant case: 3, mrr_w_penalty: 9.536, mrr: 23.450, number of cases still missing in the query 1, total missed: 1
# Query score: [0 0 0 0 0], rank of 1st relevant case: 0, mrr_w_penalty: 9.536, mrr: 23.450, number of cases still missing in the query 3, total missed: 3
# Query score: [0 0 0 0 1], rank of 1st relevant case: 5, mrr_w_penalty: 9.661, mrr: 23.650, number of cases still missing in the query 3, total missed: 3
# Query score: [0 0 0 0 0], rank of 1st relevant case: 0, mrr_w_penalty: 9.661, mrr: 23.650, number of cases still missing in the query 0, total missed: 0
# Query score: [0 0 0 0 0], rank of 1st relevant case: 0, mrr_w_penalty: 9.661, mrr: 23.650, number of cases still missing in the query 0, total missed: 0
# Query score: [0 0 0 0 0], rank of 1st relevant case: 0, mrr_w_penalty: 9.661, mrr: 23.650, number of cases still missing in the query 2, total missed: 2
# Query score: [1 1 0 1 0], rank of 1st relevant case: 1, mrr_w_penalty: 9.994, mrr: 24.650, number of cases still missing in the query 2, total missed: 6
# Query score: [0 0 0 0 0], rank of 1st relevant case: 0, mrr_w_penalty: 9.994, mrr: 24.650, number of cases still missing in the query 0, total missed: 0
# Query score: [1 0 1 1 0], rank of 1st relevant case: 1, mrr_w_penalty: 10.327, mrr: 25.650, number of cases still missing in the query 2, total missed: 6
# Query score: [0 0 0 0 0], rank of 1st relevant case: 0, mrr_w_penalty: 0.000, mrr: 0.000, number of cases still missing in the query 2, total missed: 2
# Query score: [0 0 0 0 0], rank of 1st relevant case: 0, mrr_w_penalty: 0.000, mrr: 0.000, number of cases still missing in the query 3, total missed: 3
# Query score: [0 0 0 0 0], rank of 1st relevant case: 0, mrr_w_penalty: 0.000, mrr: 0.000, number of cases still missing in the query 1, total missed: 1
# Query score: [0 0 0 0 0], rank of 1st relevant case: 0, mrr_w_penalty: 0.000, mrr: 0.000, number of cases still missing in the query 0, total missed: 0
# Query score: [0 0 0 1 0], rank of 1st relevant case: 4, mrr_w_penalty: 0.125, mrr: 0.250, number of cases still missing in the query 4, total missed: 6
# Query score: [0 0 0 0 0], rank of 1st relevant case: 0, mrr_w_penalty: 0.125, mrr: 0.250, number of cases still missing in the query 1, total missed: 1
# Query score: [0 0 1 0 0], rank of 1st relevant case: 3, mrr_w_penalty: 0.268, mrr: 0.583, number of cases still missing in the query 4, total missed: 6
# Query score: [0 0 0 0 1], rank of 1st relevant case: 5, mrr_w_penalty: 0.379, mrr: 0.783, number of cases still missing in the query 4, total missed: 10
# Query score: [1 1 1 0 0], rank of 1st relevant case: 1, mrr_w_penalty: 0.712, mrr: 1.783, number of cases still missing in the query 2, total missed: 10
# Query score: [0 0 0 0 0], rank of 1st relevant case: 0, mrr_w_penalty: 0.712, mrr: 1.783, number of cases still missing in the query 2, total missed: 2
# Query score: [0 0 0 0 0], rank of 1st relevant case: 0, mrr_w_penalty: 0.712, mrr: 1.783, number of cases still missing in the query 5, total missed: 5
# Query score: [1 0 1 1 0], rank of 1st relevant case: 1, mrr_w_penalty: 1.046, mrr: 2.783, number of cases still missing in the query 2, total missed: 9
# Query score: [0 0 0 1 0], rank of 1st relevant case: 4, mrr_w_penalty: 1.171, mrr: 3.033, number of cases still missing in the query 4, total missed: 9
# Query score: [0 0 0 0 0], rank of 1st relevant case: 0, mrr_w_penalty: 1.171, mrr: 3.033, number of cases still missing in the query 5, total missed: 5
# Query score: [1 1 0 1 1], rank of 1st relevant case: 1, mrr_w_penalty: 1.671, mrr: 4.033, number of cases still missing in the query 1, total missed: 10
# Query score: [1 1 1 1 0], rank of 1st relevant case: 1, mrr_w_penalty: 2.171, mrr: 5.033, number of cases still missing in the query 1, total missed: 9
# Query score: [1 1 0 0 0], rank of 1st relevant case: 1, mrr_w_penalty: 2.421, mrr: 6.033, number of cases still missing in the query 3, total missed: 9
# Query score: [0 0 0 0 0], rank of 1st relevant case: 0, mrr_w_penalty: 2.421, mrr: 6.033, number of cases still missing in the query 5, total missed: 5
# Query score: [1 0 1 1 0], rank of 1st relevant case: 1, mrr_w_penalty: 2.754, mrr: 7.033, number of cases still missing in the query 2, total missed: 9
# Query score: [1 0 0 0 0], rank of 1st relevant case: 1, mrr_w_penalty: 2.954, mrr: 8.033, number of cases still missing in the query 4, total missed: 10
# Query score: [1 1 1 0 0], rank of 1st relevant case: 1, mrr_w_penalty: 3.287, mrr: 9.033, number of cases still missing in the query 2, total missed: 9
# Query score: [0 0 0 0 0], rank of 1st relevant case: 0, mrr_w_penalty: 3.287, mrr: 9.033, number of cases still missing in the query 2, total missed: 2
# Query score: [0 0 0 0 0], rank of 1st relevant case: 0, mrr_w_penalty: 3.287, mrr: 9.033, number of cases still missing in the query 0, total missed: 0
# Query score: [0 0 0 0 0], rank of 1st relevant case: 0, mrr_w_penalty: 3.287, mrr: 9.033, number of cases still missing in the query 2, total missed: 2
# Query score: [0 0 0 0 0], rank of 1st relevant case: 0, mrr_w_penalty: 3.287, mrr: 9.033, number of cases still missing in the query 5, total missed: 10
# Query score: [0 1 0 0 0], rank of 1st relevant case: 2, mrr_w_penalty: 3.454, mrr: 9.533, number of cases still missing in the query 4, total missed: 9
# Query score: [0 0 0 0 0], rank of 1st relevant case: 0, mrr_w_penalty: 3.454, mrr: 9.533, number of cases still missing in the query 0, total missed: 0
# Query score: [0 0 0 0 0], rank of 1st relevant case: 0, mrr_w_penalty: 3.454, mrr: 9.533, number of cases still missing in the query 5, total missed: 10
# Query score: [0 0 0 0 0], rank of 1st relevant case: 0, mrr_w_penalty: 3.454, mrr: 9.533, number of cases still missing in the query 2, total missed: 2
# Query score: [0 0 0 1 0], rank of 1st relevant case: 4, mrr_w_penalty: 3.579, mrr: 9.783, number of cases still missing in the query 4, total missed: 6
# Query score: [0 0 1 0 0], rank of 1st relevant case: 3, mrr_w_penalty: 3.722, mrr: 10.117, number of cases still missing in the query 4, total missed: 10
# Query score: [1 1 1 1 1], rank of 1st relevant case: 1, mrr_w_penalty: 4.722, mrr: 11.117, number of cases still missing in the query 0, total missed: 7
# Query score: [1 0 0 0 0], rank of 1st relevant case: 1, mrr_w_penalty: 4.972, mrr: 12.117, number of cases still missing in the query 3, total missed: 3
# Query score: [0 0 0 0 0], rank of 1st relevant case: 0, mrr_w_penalty: 4.972, mrr: 12.117, number of cases still missing in the query 5, total missed: 10
# Query score: [1 0 0 0 0], rank of 1st relevant case: 1, mrr_w_penalty: 5.472, mrr: 13.117, number of cases still missing in the query 1, total missed: 1
# Query score: [1 0 0 0 0], rank of 1st relevant case: 1, mrr_w_penalty: 5.972, mrr: 14.117, number of cases still missing in the query 1, total missed: 1
# Query score: [0 0 0 0 0], rank of 1st relevant case: 0, mrr_w_penalty: 5.972, mrr: 14.117, number of cases still missing in the query 5, total missed: 10
# Query score: [1 0 0 0 0], rank of 1st relevant case: 1, mrr_w_penalty: 6.172, mrr: 15.117, number of cases still missing in the query 4, total missed: 10
# Query score: [0 0 0 0 0], rank of 1st relevant case: 0, mrr_w_penalty: 6.172, mrr: 15.117, number of cases still missing in the query 0, total missed: 0
# Query score: [1 0 1 1 0], rank of 1st relevant case: 1, mrr_w_penalty: 6.505, mrr: 16.117, number of cases still missing in the query 2, total missed: 6
# Query score: [0 0 1 0 0], rank of 1st relevant case: 3, mrr_w_penalty: 6.672, mrr: 16.450, number of cases still missing in the query 3, total missed: 3
# Query score: [0 0 0 0 0], rank of 1st relevant case: 0, mrr_w_penalty: 6.672, mrr: 16.450, number of cases still missing in the query 0, total missed: 0
# Query score: [0 0 0 0 0], rank of 1st relevant case: 0, mrr_w_penalty: 6.672, mrr: 16.450, number of cases still missing in the query 5, total missed: 5
# Query score: [0 0 0 0 0], rank of 1st relevant case: 0, mrr_w_penalty: 6.672, mrr: 16.450, number of cases still missing in the query 3, total missed: 3
# Query score: [0 0 0 0 0], rank of 1st relevant case: 0, mrr_w_penalty: 6.672, mrr: 16.450, number of cases still missing in the query 5, total missed: 6
# Query score: [0 0 1 0 0], rank of 1st relevant case: 3, mrr_w_penalty: 6.815, mrr: 16.783, number of cases still missing in the query 4, total missed: 6
# Query score: [0 0 0 0 0], rank of 1st relevant case: 0, mrr_w_penalty: 6.815, mrr: 16.783, number of cases still missing in the query 1, total missed: 1
# Query score: [0 0 0 0 0], rank of 1st relevant case: 0, mrr_w_penalty: 6.815, mrr: 16.783, number of cases still missing in the query 0, total missed: 0
# Query score: [0 0 0 0 0], rank of 1st relevant case: 0, mrr_w_penalty: 6.815, mrr: 16.783, number of cases still missing in the query 5, total missed: 9
# Query score: [1 0 0 0 0], rank of 1st relevant case: 1, mrr_w_penalty: 7.315, mrr: 17.783, number of cases still missing in the query 1, total missed: 1
# Query score: [1 1 0 1 1], rank of 1st relevant case: 1, mrr_w_penalty: 7.815, mrr: 18.783, number of cases still missing in the query 1, total missed: 10
# Query score: [0 0 1 1 0], rank of 1st relevant case: 3, mrr_w_penalty: 7.981, mrr: 19.117, number of cases still missing in the query 3, total missed: 3
# Query score: [1 0 1 0 1], rank of 1st relevant case: 1, mrr_w_penalty: 8.315, mrr: 20.117, number of cases still missing in the query 2, total missed: 9
# Query score: [0 0 1 0 0], rank of 1st relevant case: 3, mrr_w_penalty: 8.481, mrr: 20.450, number of cases still missing in the query 3, total missed: 3
# Query score: [0 0 0 0 0], rank of 1st relevant case: 0, mrr_w_penalty: 8.481, mrr: 20.450, number of cases still missing in the query 2, total missed: 2
# Query score: [0 0 0 0 0], rank of 1st relevant case: 0, mrr_w_penalty: 8.481, mrr: 20.450, number of cases still missing in the query 0, total missed: 0
# Query score: [0 0 0 0 0], rank of 1st relevant case: 0, mrr_w_penalty: 8.481, mrr: 20.450, number of cases still missing in the query 0, total missed: 0
# Query score: [1 0 0 0 0], rank of 1st relevant case: 1, mrr_w_penalty: 8.731, mrr: 21.450, number of cases still missing in the query 3, total missed: 3
# Query score: [0 0 0 0 0], rank of 1st relevant case: 0, mrr_w_penalty: 8.731, mrr: 21.450, number of cases still missing in the query 2, total missed: 2
# Query score: [1 1 1 0 0], rank of 1st relevant case: 1, mrr_w_penalty: 9.065, mrr: 22.450, number of cases still missing in the query 2, total missed: 9
# Query score: [1 0 0 0 0], rank of 1st relevant case: 1, mrr_w_penalty: 9.565, mrr: 23.450, number of cases still missing in the query 1, total missed: 1
# Query score: [0 0 0 0 0], rank of 1st relevant case: 0, mrr_w_penalty: 9.565, mrr: 23.450, number of cases still missing in the query 3, total missed: 3
# Query score: [0 0 0 0 0], rank of 1st relevant case: 0, mrr_w_penalty: 9.565, mrr: 23.450, number of cases still missing in the query 3, total missed: 3
# Query score: [0 0 0 0 0], rank of 1st relevant case: 0, mrr_w_penalty: 9.565, mrr: 23.450, number of cases still missing in the query 0, total missed: 0
# Query score: [0 0 0 0 0], rank of 1st relevant case: 0, mrr_w_penalty: 9.565, mrr: 23.450, number of cases still missing in the query 0, total missed: 0
# Query score: [0 0 0 0 0], rank of 1st relevant case: 0, mrr_w_penalty: 9.565, mrr: 23.450, number of cases still missing in the query 2, total missed: 2
# Query score: [1 0 1 1 0], rank of 1st relevant case: 1, mrr_w_penalty: 9.898, mrr: 24.450, number of cases still missing in the query 2, total missed: 6
# Query score: [0 0 0 0 0], rank of 1st relevant case: 0, mrr_w_penalty: 9.898, mrr: 24.450, number of cases still missing in the query 0, total missed: 0
# Query score: [1 0 1 0 1], rank of 1st relevant case: 1, mrr_w_penalty: 10.231, mrr: 25.450, number of cases still missing in the query 2, total missed: 6
# Query score: [0 0 0 0 0], rank of 1st relevant case: 0, mrr_w_penalty: 0.000, mrr: 0.000, number of cases still missing in the query 2, total missed: 2
# Query score: [0 0 0 0 0], rank of 1st relevant case: 0, mrr_w_penalty: 0.000, mrr: 0.000, number of cases still missing in the query 3, total missed: 3
# Query score: [0 0 0 0 0], rank of 1st relevant case: 0, mrr_w_penalty: 0.000, mrr: 0.000, number of cases still missing in the query 1, total missed: 1
# Query score: [0 0 0 0 0], rank of 1st relevant case: 0, mrr_w_penalty: 0.000, mrr: 0.000, number of cases still missing in the query 0, total missed: 0
# Query score: [0 0 0 0 0], rank of 1st relevant case: 0, mrr_w_penalty: 0.000, mrr: 0.000, number of cases still missing in the query 5, total missed: 6
# Query score: [0 0 0 0 0], rank of 1st relevant case: 0, mrr_w_penalty: 0.000, mrr: 0.000, number of cases still missing in the query 1, total missed: 1
# Query score: [0 0 0 0 0], rank of 1st relevant case: 0, mrr_w_penalty: 0.000, mrr: 0.000, number of cases still missing in the query 5, total missed: 5
# Query score: [0 0 0 0 1], rank of 1st relevant case: 5, mrr_w_penalty: 0.111, mrr: 0.200, number of cases still missing in the query 4, total missed: 10
# Query score: [1 1 0 0 0], rank of 1st relevant case: 1, mrr_w_penalty: 0.361, mrr: 1.200, number of cases still missing in the query 3, total missed: 10
# Query score: [0 0 0 0 0], rank of 1st relevant case: 0, mrr_w_penalty: 0.361, mrr: 1.200, number of cases still missing in the query 2, total missed: 2
# Query score: [0 0 0 0 0], rank of 1st relevant case: 0, mrr_w_penalty: 0.361, mrr: 1.200, number of cases still missing in the query 5, total missed: 5
# Query score: [1 0 1 1 0], rank of 1st relevant case: 1, mrr_w_penalty: 0.694, mrr: 2.200, number of cases still missing in the query 2, total missed: 9
# Query score: [0 1 0 0 0], rank of 1st relevant case: 2, mrr_w_penalty: 0.861, mrr: 2.700, number of cases still missing in the query 4, total missed: 9
# Query score: [0 0 0 0 1], rank of 1st relevant case: 5, mrr_w_penalty: 0.972, mrr: 2.900, number of cases still missing in the query 4, total missed: 5
# Query score: [1 1 0 0 0], rank of 1st relevant case: 1, mrr_w_penalty: 1.222, mrr: 3.900, number of cases still missing in the query 3, total missed: 10
# Query score: [1 1 1 1 1], rank of 1st relevant case: 1, mrr_w_penalty: 2.222, mrr: 4.900, number of cases still missing in the query 0, total missed: 9
# Query score: [0 0 0 1 1], rank of 1st relevant case: 4, mrr_w_penalty: 2.365, mrr: 5.150, number of cases still missing in the query 3, total missed: 9
# Query score: [0 1 0 0 0], rank of 1st relevant case: 2, mrr_w_penalty: 2.532, mrr: 5.650, number of cases still missing in the query 4, total missed: 6
# Query score: [1 0 1 0 0], rank of 1st relevant case: 1, mrr_w_penalty: 2.782, mrr: 6.650, number of cases still missing in the query 3, total missed: 9
# Query score: [1 0 0 0 0], rank of 1st relevant case: 1, mrr_w_penalty: 2.982, mrr: 7.650, number of cases still missing in the query 4, total missed: 10
# Query score: [1 0 1 1 0], rank of 1st relevant case: 1, mrr_w_penalty: 3.315, mrr: 8.650, number of cases still missing in the query 2, total missed: 9
# Query score: [0 0 0 1 0], rank of 1st relevant case: 4, mrr_w_penalty: 3.482, mrr: 8.900, number of cases still missing in the query 2, total missed: 2
# Query score: [0 0 0 0 0], rank of 1st relevant case: 0, mrr_w_penalty: 3.482, mrr: 8.900, number of cases still missing in the query 0, total missed: 0
# Query score: [0 0 0 0 0], rank of 1st relevant case: 0, mrr_w_penalty: 3.482, mrr: 8.900, number of cases still missing in the query 2, total missed: 2
# Query score: [0 0 0 0 0], rank of 1st relevant case: 0, mrr_w_penalty: 3.482, mrr: 8.900, number of cases still missing in the query 5, total missed: 10
# Query score: [0 0 0 0 0], rank of 1st relevant case: 0, mrr_w_penalty: 3.482, mrr: 8.900, number of cases still missing in the query 5, total missed: 9
# Query score: [0 0 0 0 0], rank of 1st relevant case: 0, mrr_w_penalty: 3.482, mrr: 8.900, number of cases still missing in the query 0, total missed: 0
# Query score: [0 0 0 0 0], rank of 1st relevant case: 0, mrr_w_penalty: 3.482, mrr: 8.900, number of cases still missing in the query 5, total missed: 10
# Query score: [0 0 0 0 0], rank of 1st relevant case: 0, mrr_w_penalty: 3.482, mrr: 8.900, number of cases still missing in the query 2, total missed: 2
# Query score: [0 0 0 0 0], rank of 1st relevant case: 0, mrr_w_penalty: 3.482, mrr: 8.900, number of cases still missing in the query 5, total missed: 5
# Query score: [0 0 1 0 0], rank of 1st relevant case: 3, mrr_w_penalty: 3.625, mrr: 9.233, number of cases still missing in the query 4, total missed: 10
# Query score: [1 1 0 0 1], rank of 1st relevant case: 1, mrr_w_penalty: 3.958, mrr: 10.233, number of cases still missing in the query 2, total missed: 6
# Query score: [1 0 0 0 0], rank of 1st relevant case: 1, mrr_w_penalty: 4.208, mrr: 11.233, number of cases still missing in the query 3, total missed: 3
# Query score: [0 0 0 0 1], rank of 1st relevant case: 5, mrr_w_penalty: 4.319, mrr: 11.433, number of cases still missing in the query 4, total missed: 10
# Query score: [1 0 0 0 0], rank of 1st relevant case: 1, mrr_w_penalty: 4.819, mrr: 12.433, number of cases still missing in the query 1, total missed: 1
# Query score: [0 0 0 1 0], rank of 1st relevant case: 4, mrr_w_penalty: 5.019, mrr: 12.683, number of cases still missing in the query 1, total missed: 1
# Query score: [0 0 0 0 0], rank of 1st relevant case: 0, mrr_w_penalty: 5.019, mrr: 12.683, number of cases still missing in the query 5, total missed: 10
# Query score: [0 0 0 0 0], rank of 1st relevant case: 0, mrr_w_penalty: 5.019, mrr: 12.683, number of cases still missing in the query 5, total missed: 10
# Query score: [0 0 0 0 0], rank of 1st relevant case: 0, mrr_w_penalty: 5.019, mrr: 12.683, number of cases still missing in the query 0, total missed: 0
# Query score: [1 1 0 1 0], rank of 1st relevant case: 1, mrr_w_penalty: 5.352, mrr: 13.683, number of cases still missing in the query 2, total missed: 6
# Query score: [0 0 0 0 0], rank of 1st relevant case: 0, mrr_w_penalty: 5.352, mrr: 13.683, number of cases still missing in the query 3, total missed: 3
# Query score: [0 0 0 0 0], rank of 1st relevant case: 0, mrr_w_penalty: 5.352, mrr: 13.683, number of cases still missing in the query 0, total missed: 0
# Query score: [0 0 0 0 0], rank of 1st relevant case: 0, mrr_w_penalty: 5.352, mrr: 13.683, number of cases still missing in the query 5, total missed: 5
# Query score: [0 0 1 0 0], rank of 1st relevant case: 3, mrr_w_penalty: 5.495, mrr: 14.017, number of cases still missing in the query 4, total missed: 4
# Query score: [0 0 0 0 0], rank of 1st relevant case: 0, mrr_w_penalty: 5.495, mrr: 14.017, number of cases still missing in the query 5, total missed: 6
# Query score: [0 0 0 0 0], rank of 1st relevant case: 0, mrr_w_penalty: 5.495, mrr: 14.017, number of cases still missing in the query 5, total missed: 6
# Query score: [0 0 0 0 0], rank of 1st relevant case: 0, mrr_w_penalty: 5.495, mrr: 14.017, number of cases still missing in the query 1, total missed: 1
# Query score: [0 0 0 0 0], rank of 1st relevant case: 0, mrr_w_penalty: 5.495, mrr: 14.017, number of cases still missing in the query 0, total missed: 0
# Query score: [0 1 0 1 0], rank of 1st relevant case: 2, mrr_w_penalty: 5.695, mrr: 14.517, number of cases still missing in the query 3, total missed: 9
# Query score: [1 0 0 0 0], rank of 1st relevant case: 1, mrr_w_penalty: 6.195, mrr: 15.517, number of cases still missing in the query 1, total missed: 1
# Query score: [1 1 0 0 0], rank of 1st relevant case: 1, mrr_w_penalty: 6.445, mrr: 16.517, number of cases still missing in the query 3, total missed: 10
# Query score: [1 0 0 0 0], rank of 1st relevant case: 1, mrr_w_penalty: 6.695, mrr: 17.517, number of cases still missing in the query 3, total missed: 3
# Query score: [1 1 1 1 0], rank of 1st relevant case: 1, mrr_w_penalty: 7.195, mrr: 18.517, number of cases still missing in the query 1, total missed: 9
# Query score: [0 1 0 0 0], rank of 1st relevant case: 2, mrr_w_penalty: 7.395, mrr: 19.017, number of cases still missing in the query 3, total missed: 3
# Query score: [0 0 0 0 1], rank of 1st relevant case: 5, mrr_w_penalty: 7.538, mrr: 19.217, number of cases still missing in the query 2, total missed: 2
# Query score: [0 0 0 0 0], rank of 1st relevant case: 0, mrr_w_penalty: 7.538, mrr: 19.217, number of cases still missing in the query 0, total missed: 0
# Query score: [0 0 0 0 0], rank of 1st relevant case: 0, mrr_w_penalty: 7.538, mrr: 19.217, number of cases still missing in the query 0, total missed: 0
# Query score: [0 0 0 0 0], rank of 1st relevant case: 0, mrr_w_penalty: 7.538, mrr: 19.217, number of cases still missing in the query 3, total missed: 3
# Query score: [1 0 0 0 0], rank of 1st relevant case: 1, mrr_w_penalty: 7.871, mrr: 20.217, number of cases still missing in the query 2, total missed: 2
# Query score: [1 1 1 1 0], rank of 1st relevant case: 1, mrr_w_penalty: 8.371, mrr: 21.217, number of cases still missing in the query 1, total missed: 9
# Query score: [1 0 0 0 0], rank of 1st relevant case: 1, mrr_w_penalty: 8.871, mrr: 22.217, number of cases still missing in the query 1, total missed: 1
# Query score: [0 0 0 0 0], rank of 1st relevant case: 0, mrr_w_penalty: 8.871, mrr: 22.217, number of cases still missing in the query 3, total missed: 3
# Query score: [0 0 0 0 0], rank of 1st relevant case: 0, mrr_w_penalty: 8.871, mrr: 22.217, number of cases still missing in the query 3, total missed: 3
# Query score: [0 0 0 0 0], rank of 1st relevant case: 0, mrr_w_penalty: 8.871, mrr: 22.217, number of cases still missing in the query 0, total missed: 0
# Query score: [0 0 0 0 0], rank of 1st relevant case: 0, mrr_w_penalty: 8.871, mrr: 22.217, number of cases still missing in the query 0, total missed: 0
# Query score: [0 0 0 0 0], rank of 1st relevant case: 0, mrr_w_penalty: 8.871, mrr: 22.217, number of cases still missing in the query 2, total missed: 2
# Query score: [1 1 1 0 0], rank of 1st relevant case: 1, mrr_w_penalty: 9.205, mrr: 23.217, number of cases still missing in the query 2, total missed: 6
# Query score: [0 0 0 0 0], rank of 1st relevant case: 0, mrr_w_penalty: 9.205, mrr: 23.217, number of cases still missing in the query 0, total missed: 0
# Query score: [1 1 1 0 0], rank of 1st relevant case: 1, mrr_w_penalty: 9.538, mrr: 24.217, number of cases still missing in the query 2, total missed: 6
# Query score: [1 0 0 0 0], rank of 1st relevant case: 1, mrr_w_penalty: 0.500, mrr: 1.000, number of cases still missing in the query 1, total missed: 1
# Query score: [0 0 0 0 0], rank of 1st relevant case: 0, mrr_w_penalty: 0.500, mrr: 1.000, number of cases still missing in the query 2, total missed: 2
# Query score: [0 0 0 0 0], rank of 1st relevant case: 0, mrr_w_penalty: 0.500, mrr: 1.000, number of cases still missing in the query 0, total missed: 0
# Query score: [0 0 0 0 0], rank of 1st relevant case: 0, mrr_w_penalty: 0.500, mrr: 1.000, number of cases still missing in the query 0, total missed: 0
# Query score: [0 1 0 0 0], rank of 1st relevant case: 2, mrr_w_penalty: 0.667, mrr: 1.500, number of cases still missing in the query 4, total missed: 6
# Query score: [0 0 0 0 0], rank of 1st relevant case: 0, mrr_w_penalty: 0.667, mrr: 1.500, number of cases still missing in the query 0, total missed: 0
# Query score: [1 0 1 0 0], rank of 1st relevant case: 1, mrr_w_penalty: 0.917, mrr: 2.500, number of cases still missing in the query 3, total missed: 5
# Query score: [1 0 0 1 0], rank of 1st relevant case: 1, mrr_w_penalty: 1.167, mrr: 3.500, number of cases still missing in the query 3, total missed: 10
# Query score: [1 1 0 0 0], rank of 1st relevant case: 1, mrr_w_penalty: 1.417, mrr: 4.500, number of cases still missing in the query 3, total missed: 10
# Query score: [0 0 0 0 0], rank of 1st relevant case: 0, mrr_w_penalty: 1.417, mrr: 4.500, number of cases still missing in the query 2, total missed: 2
# Query score: [0 0 0 0 0], rank of 1st relevant case: 0, mrr_w_penalty: 1.417, mrr: 4.500, number of cases still missing in the query 5, total missed: 5
# Query score: [1 0 0 0 0], rank of 1st relevant case: 1, mrr_w_penalty: 1.617, mrr: 5.500, number of cases still missing in the query 4, total missed: 9
# Query score: [0 0 0 1 0], rank of 1st relevant case: 4, mrr_w_penalty: 1.742, mrr: 5.750, number of cases still missing in the query 4, total missed: 9
# Query score: [0 0 0 0 0], rank of 1st relevant case: 0, mrr_w_penalty: 1.742, mrr: 5.750, number of cases still missing in the query 5, total missed: 5
# Query score: [1 1 0 0 0], rank of 1st relevant case: 1, mrr_w_penalty: 1.992, mrr: 6.750, number of cases still missing in the query 3, total missed: 10
# Query score: [1 1 0 1 1], rank of 1st relevant case: 1, mrr_w_penalty: 2.492, mrr: 7.750, number of cases still missing in the query 1, total missed: 9
# Query score: [1 0 1 0 0], rank of 1st relevant case: 1, mrr_w_penalty: 2.742, mrr: 8.750, number of cases still missing in the query 3, total missed: 9
# Query score: [1 1 0 0 0], rank of 1st relevant case: 1, mrr_w_penalty: 2.992, mrr: 9.750, number of cases still missing in the query 3, total missed: 5
# Query score: [1 1 0 0 0], rank of 1st relevant case: 1, mrr_w_penalty: 3.242, mrr: 10.750, number of cases still missing in the query 3, total missed: 9
# Query score: [1 0 0 0 0], rank of 1st relevant case: 1, mrr_w_penalty: 3.442, mrr: 11.750, number of cases still missing in the query 4, total missed: 10
# Query score: [1 0 0 0 0], rank of 1st relevant case: 1, mrr_w_penalty: 3.642, mrr: 12.750, number of cases still missing in the query 4, total missed: 9
# Query score: [0 0 1 0 0], rank of 1st relevant case: 3, mrr_w_penalty: 3.892, mrr: 13.083, number of cases still missing in the query 1, total missed: 1
# Query score: [0 0 0 0 0], rank of 1st relevant case: 0, mrr_w_penalty: 3.892, mrr: 13.083, number of cases still missing in the query 0, total missed: 0
# Query score: [1 0 0 0 0], rank of 1st relevant case: 1, mrr_w_penalty: 4.392, mrr: 14.083, number of cases still missing in the query 1, total missed: 1
# Query score: [0 1 0 1 0], rank of 1st relevant case: 2, mrr_w_penalty: 4.592, mrr: 14.583, number of cases still missing in the query 3, total missed: 10
# Query score: [0 1 0 0 0], rank of 1st relevant case: 2, mrr_w_penalty: 4.758, mrr: 15.083, number of cases still missing in the query 4, total missed: 9
# Query score: [0 0 0 0 0], rank of 1st relevant case: 0, mrr_w_penalty: 4.758, mrr: 15.083, number of cases still missing in the query 0, total missed: 0
# Query score: [0 0 0 0 0], rank of 1st relevant case: 0, mrr_w_penalty: 4.758, mrr: 15.083, number of cases still missing in the query 5, total missed: 10
# Query score: [1 0 0 0 0], rank of 1st relevant case: 1, mrr_w_penalty: 5.258, mrr: 16.083, number of cases still missing in the query 1, total missed: 1
# Query score: [1 1 0 0 0], rank of 1st relevant case: 1, mrr_w_penalty: 5.508, mrr: 17.083, number of cases still missing in the query 3, total missed: 5
# Query score: [0 1 1 1 1], rank of 1st relevant case: 2, mrr_w_penalty: 5.842, mrr: 17.583, number of cases still missing in the query 1, total missed: 10
# Query score: [1 1 1 0 0], rank of 1st relevant case: 1, mrr_w_penalty: 6.175, mrr: 18.583, number of cases still missing in the query 2, total missed: 6
# Query score: [0 1 0 0 0], rank of 1st relevant case: 2, mrr_w_penalty: 6.375, mrr: 19.083, number of cases still missing in the query 3, total missed: 3
# Query score: [1 0 0 1 1], rank of 1st relevant case: 1, mrr_w_penalty: 6.708, mrr: 20.083, number of cases still missing in the query 2, total missed: 10
# Query score: [1 0 0 0 0], rank of 1st relevant case: 1, mrr_w_penalty: 7.208, mrr: 21.083, number of cases still missing in the query 1, total missed: 1
# Query score: [0 0 0 0 0], rank of 1st relevant case: 0, mrr_w_penalty: 7.208, mrr: 21.083, number of cases still missing in the query 1, total missed: 1
# Query score: [0 0 0 0 1], rank of 1st relevant case: 5, mrr_w_penalty: 7.319, mrr: 21.283, number of cases still missing in the query 4, total missed: 10
# ...
# Query score: [1 0 0 0 0], rank of 1st relevant case: 1, mrr_w_penalty: 5.502, mrr: 15.367, number of cases still missing in the query 1, total missed: 1
# Query score: [1 0 0 0 0], rank of 1st relevant case: 1, mrr_w_penalty: 6.002, mrr: 16.367, number of cases still missing in the query 1, total missed: 1
# Query score: [0 0 1 0 0], rank of 1st relevant case: 3, mrr_w_penalty: 6.145, mrr: 16.700, number of cases still missing in the query 4, total missed: 10
# Query score: [1 0 1 0 0], rank of 1st relevant case: 1, mrr_w_penalty: 6.395, mrr: 17.700, number of cases still missing in the query 3, total missed: 10
# Query score: [0 0 0 0 0], rank of 1st relevant case: 0, mrr_w_penalty: 6.395, mrr: 17.700, number of cases still missing in the query 0, total missed: 0
# Query score: [1 0 1 0 0], rank of 1st relevant case: 1, mrr_w_penalty: 6.645, mrr: 18.700, number of cases still missing in the query 3, total missed: 6
# Query score: [0 1 1 0 0], rank of 1st relevant case: 2, mrr_w_penalty: 6.845, mrr: 19.200, number of cases still missing in the query 3, total missed: 3
# Query score: [0 0 0 0 0], rank of 1st relevant case: 0, mrr_w_penalty: 6.845, mrr: 19.200, number of cases still missing in the query 0, total missed: 0
# Query score: [0 0 0 0 0], rank of 1st relevant case: 0, mrr_w_penalty: 6.845, mrr: 19.200, number of cases still missing in the query 5, total missed: 5
# Query score: [1 1 0 0 0], rank of 1st relevant case: 1, mrr_w_penalty: 7.095, mrr: 20.200, number of cases still missing in the query 3, total missed: 4
# Query score: [0 0 0 0 0], rank of 1st relevant case: 0, mrr_w_penalty: 7.095, mrr: 20.200, number of cases still missing in the query 5, total missed: 6
# Query score: [1 1 0 0 0], rank of 1st relevant case: 1, mrr_w_penalty: 7.345, mrr: 21.200, number of cases still missing in the query 3, total missed: 7
# Query score: [0 0 0 0 0], rank of 1st relevant case: 0, mrr_w_penalty: 7.345, mrr: 21.200, number of cases still missing in the query 1, total missed: 1
# Query score: [0 0 0 0 0], rank of 1st relevant case: 0, mrr_w_penalty: 7.345, mrr: 21.200, number of cases still missing in the query 0, total missed: 0
# Query score: [0 1 0 0 1], rank of 1st relevant case: 2, mrr_w_penalty: 7.545, mrr: 21.700, number of cases still missing in the query 3, total missed: 9
# Query score: [1 0 0 0 0], rank of 1st relevant case: 1, mrr_w_penalty: 8.045, mrr: 22.700, number of cases still missing in the query 1, total missed: 1
# Query score: [1 1 1 0 0], rank of 1st relevant case: 1, mrr_w_penalty: 8.379, mrr: 23.700, number of cases still missing in the query 2, total missed: 10
# Query score: [1 0 0 0 0], rank of 1st relevant case: 1, mrr_w_penalty: 8.629, mrr: 24.700, number of cases still missing in the query 3, total missed: 3
# Query score: [1 1 0 0 1], rank of 1st relevant case: 1, mrr_w_penalty: 8.962, mrr: 25.700, number of cases still missing in the query 2, total missed: 10
# Query score: [1 0 0 0 1], rank of 1st relevant case: 1, mrr_w_penalty: 9.212, mrr: 26.700, number of cases still missing in the query 3, total missed: 3
# Query score: [0 0 0 0 0], rank of 1st relevant case: 0, mrr_w_penalty: 9.212, mrr: 26.700, number of cases still missing in the query 2, total missed: 2
# Query score: [0 0 0 0 0], rank of 1st relevant case: 0, mrr_w_penalty: 9.212, mrr: 26.700, number of cases still missing in the query 0, total missed: 0
# Query score: [0 0 0 0 0], rank of 1st relevant case: 0, mrr_w_penalty: 9.212, mrr: 26.700, number of cases still missing in the query 1, total missed: 1
# Query score: [1 0 0 0 1], rank of 1st relevant case: 1, mrr_w_penalty: 9.462, mrr: 27.700, number of cases still missing in the query 3, total missed: 3
# Query score: [0 1 0 0 0], rank of 1st relevant case: 2, mrr_w_penalty: 9.712, mrr: 28.200, number of cases still missing in the query 2, total missed: 2
# Query score: [1 0 0 0 0], rank of 1st relevant case: 1, mrr_w_penalty: 9.912, mrr: 29.200, number of cases still missing in the query 4, total missed: 9
# Query score: [1 0 0 0 0], rank of 1st relevant case: 1, mrr_w_penalty: 10.412, mrr: 30.200, number of cases still missing in the query 1, total missed: 1
# Query score: [0 0 0 1 0], rank of 1st relevant case: 4, mrr_w_penalty: 10.555, mrr: 30.450, number of cases still missing in the query 3, total missed: 3
# Query score: [0 0 0 0 0], rank of 1st relevant case: 0, mrr_w_penalty: 10.555, mrr: 30.450, number of cases still missing in the query 3, total missed: 3
# Query score: [0 0 0 0 0], rank of 1st relevant case: 0, mrr_w_penalty: 10.555, mrr: 30.450, number of cases still missing in the query 0, total missed: 0
# Query score: [0 0 0 0 0], rank of 1st relevant case: 0, mrr_w_penalty: 10.555, mrr: 30.450, number of cases still missing in the query 0, total missed: 0
# Query score: [0 0 0 0 0], rank of 1st relevant case: 0, mrr_w_penalty: 10.555, mrr: 30.450, number of cases still missing in the query 2, total missed: 2
# Query score: [1 1 0 0 1], rank of 1st relevant case: 1, mrr_w_penalty: 10.888, mrr: 31.450, number of cases still missing in the query 2, total missed: 6
# Query score: [0 0 0 0 0], rank of 1st relevant case: 0, mrr_w_penalty: 10.888, mrr: 31.450, number of cases still missing in the query 0, total missed: 0
# Query score: [1 0 0 1 1], rank of 1st relevant case: 1, mrr_w_penalty: 11.221, mrr: 32.450, number of cases still missing in the query 2, total missed: 6
# Query score: [0 0 0 0 0], rank of 1st relevant case: 0, mrr_w_penalty: 0.000, mrr: 0.000, number of cases still missing in the query 1, total missed: 1
# Query score: [0 0 0 0 0], rank of 1st relevant case: 0, mrr_w_penalty: 0.000, mrr: 0.000, number of cases still missing in the query 3, total missed: 3
# Query score: [0 0 0 0 0], rank of 1st relevant case: 0, mrr_w_penalty: 0.000, mrr: 0.000, number of cases still missing in the query 1, total missed: 1
# Query score: [0 0 0 0 0], rank of 1st relevant case: 0, mrr_w_penalty: 0.000, mrr: 0.000, number of cases still missing in the query 0, total missed: 0
# Query score: [0 0 0 0 0], rank of 1st relevant case: 0, mrr_w_penalty: 0.000, mrr: 0.000, number of cases still missing in the query 5, total missed: 7
# Query score: [0 0 0 0 0], rank of 1st relevant case: 0, mrr_w_penalty: 0.000, mrr: 0.000, number of cases still missing in the query 1, total missed: 1
# Query score: [0 0 0 0 0], rank of 1st relevant case: 0, mrr_w_penalty: 0.000, mrr: 0.000, number of cases still missing in the query 5, total missed: 5
# Query score: [1 0 1 0 0], rank of 1st relevant case: 1, mrr_w_penalty: 0.250, mrr: 1.000, number of cases still missing in the query 3, total missed: 10
# Query score: [1 1 0 0 0], rank of 1st relevant case: 1, mrr_w_penalty: 0.500, mrr: 2.000, number of cases still missing in the query 3, total missed: 10
# Query score: [0 0 0 0 0], rank of 1st relevant case: 0, mrr_w_penalty: 0.500, mrr: 2.000, number of cases still missing in the query 2, total missed: 2
# Query score: [0 0 0 0 0], rank of 1st relevant case: 0, mrr_w_penalty: 0.500, mrr: 2.000, number of cases still missing in the query 5, total missed: 5
# Query score: [1 0 0 0 0], rank of 1st relevant case: 1, mrr_w_penalty: 0.700, mrr: 3.000, number of cases still missing in the query 4, total missed: 9
# Query score: [0 0 0 0 0], rank of 1st relevant case: 0, mrr_w_penalty: 0.700, mrr: 3.000, number of cases still missing in the query 5, total missed: 9
# Query score: [0 0 1 0 1], rank of 1st relevant case: 3, mrr_w_penalty: 0.867, mrr: 3.333, number of cases still missing in the query 3, total missed: 5
# Query score: [1 1 0 0 0], rank of 1st relevant case: 1, mrr_w_penalty: 1.117, mrr: 4.333, number of cases still missing in the query 3, total missed: 10
# Query score: [1 1 1 1 1], rank of 1st relevant case: 1, mrr_w_penalty: 2.117, mrr: 5.333, number of cases still missing in the query 0, total missed: 9
# Query score: [0 0 0 1 1], rank of 1st relevant case: 4, mrr_w_penalty: 2.260, mrr: 5.583, number of cases still missing in the query 3, total missed: 9
# Query score: [1 0 1 0 0], rank of 1st relevant case: 1, mrr_w_penalty: 2.510, mrr: 6.583, number of cases still missing in the query 3, total missed: 6
# Query score: [1 1 0 0 0], rank of 1st relevant case: 1, mrr_w_penalty: 2.760, mrr: 7.583, number of cases still missing in the query 3, total missed: 9
# Query score: [1 0 0 0 0], rank of 1st relevant case: 1, mrr_w_penalty: 2.960, mrr: 8.583, number of cases still missing in the query 4, total missed: 10
# Query score: [1 0 0 0 0], rank of 1st relevant case: 1, mrr_w_penalty: 3.160, mrr: 9.583, number of cases still missing in the query 4, total missed: 9
# Query score: [0 0 1 0 0], rank of 1st relevant case: 3, mrr_w_penalty: 3.360, mrr: 9.917, number of cases still missing in the query 2, total missed: 2
# Query score: [0 0 0 0 0], rank of 1st relevant case: 0, mrr_w_penalty: 3.360, mrr: 9.917, number of cases still missing in the query 0, total missed: 0
# Query score: [0 0 0 0 0], rank of 1st relevant case: 0, mrr_w_penalty: 3.360, mrr: 9.917, number of cases still missing in the query 2, total missed: 2
# Query score: [0 0 1 0 0], rank of 1st relevant case: 3, mrr_w_penalty: 3.502, mrr: 10.250, number of cases still missing in the query 4, total missed: 10
# Query score: [0 0 1 0 0], rank of 1st relevant case: 3, mrr_w_penalty: 3.645, mrr: 10.583, number of cases still missing in the query 4, total missed: 9
# Query score: [0 0 0 0 0], rank of 1st relevant case: 0, mrr_w_penalty: 3.645, mrr: 10.583, number of cases still missing in the query 0, total missed: 0
# Query score: [0 0 0 0 0], rank of 1st relevant case: 0, mrr_w_penalty: 3.645, mrr: 10.583, number of cases still missing in the query 5, total missed: 10
# Query score: [0 0 0 0 0], rank of 1st relevant case: 0, mrr_w_penalty: 3.645, mrr: 10.583, number of cases still missing in the query 2, total missed: 2
# Query score: [0 0 0 0 0], rank of 1st relevant case: 0, mrr_w_penalty: 3.645, mrr: 10.583, number of cases still missing in the query 5, total missed: 6
# Query score: [1 1 0 1 1], rank of 1st relevant case: 1, mrr_w_penalty: 4.145, mrr: 11.583, number of cases still missing in the query 1, total missed: 11
# Query score: [1 1 0 0 0], rank of 1st relevant case: 1, mrr_w_penalty: 4.395, mrr: 12.583, number of cases still missing in the query 3, total missed: 6
# Query score: [0 1 0 0 0], rank of 1st relevant case: 2, mrr_w_penalty: 4.595, mrr: 13.083, number of cases still missing in the query 3, total missed: 3
# Query score: [0 0 0 1 1], rank of 1st relevant case: 4, mrr_w_penalty: 4.738, mrr: 13.333, number of cases still missing in the query 3, total missed: 10
# Query score: [1 0 0 0 0], rank of 1st relevant case: 1, mrr_w_penalty: 5.238, mrr: 14.333, number of cases still missing in the query 1, total missed: 1
# Query score: [0 0 0 1 0], rank of 1st relevant case: 4, mrr_w_penalty: 5.438, mrr: 14.583, number of cases still missing in the query 1, total missed: 1
# Query score: [0 1 0 0 0], rank of 1st relevant case: 2, mrr_w_penalty: 5.605, mrr: 15.083, number of cases still missing in the query 4, total missed: 10
# Query score: [0 1 0 0 0], rank of 1st relevant case: 2, mrr_w_penalty: 5.771, mrr: 15.583, number of cases still missing in the query 4, total missed: 10
# Query score: [0 0 0 0 0], rank of 1st relevant case: 0, mrr_w_penalty: 5.771, mrr: 15.583, number of cases still missing in the query 0, total missed: 0
# Query score: [1 1 1 0 0], rank of 1st relevant case: 1, mrr_w_penalty: 6.105, mrr: 16.583, number of cases still missing in the query 2, total missed: 6
# Query score: [0 0 0 0 0], rank of 1st relevant case: 0, mrr_w_penalty: 6.105, mrr: 16.583, number of cases still missing in the query 3, total missed: 3
# Query score: [0 1 0 0 0], rank of 1st relevant case: 2, mrr_w_penalty: 6.438, mrr: 17.083, number of cases still missing in the query 1, total missed: 1
# Query score: [0 0 0 0 0], rank of 1st relevant case: 0, mrr_w_penalty: 6.438, mrr: 17.083, number of cases still missing in the query 5, total missed: 5
# Query score: [0 0 0 0 0], rank of 1st relevant case: 0, mrr_w_penalty: 6.438, mrr: 17.083, number of cases still missing in the query 3, total missed: 3
# Query score: [0 0 0 0 0], rank of 1st relevant case: 0, mrr_w_penalty: 6.438, mrr: 17.083, number of cases still missing in the query 5, total missed: 6
# Query score: [1 0 0 0 0], rank of 1st relevant case: 1, mrr_w_penalty: 6.638, mrr: 18.083, number of cases still missing in the query 4, total missed: 7
# Query score: [0 0 0 0 0], rank of 1st relevant case: 0, mrr_w_penalty: 6.638, mrr: 18.083, number of cases still missing in the query 1, total missed: 1
# Query score: [0 0 0 0 0], rank of 1st relevant case: 0, mrr_w_penalty: 6.638, mrr: 18.083, number of cases still missing in the query 0, total missed: 0
# Query score: [1 0 0 0 0], rank of 1st relevant case: 1, mrr_w_penalty: 6.838, mrr: 19.083, number of cases still missing in the query 4, total missed: 9
# Query score: [1 0 0 0 0], rank of 1st relevant case: 1, mrr_w_penalty: 7.338, mrr: 20.083, number of cases still missing in the query 1, total missed: 1
# Query score: [1 1 0 0 0], rank of 1st relevant case: 1, mrr_w_penalty: 7.588, mrr: 21.083, number of cases still missing in the query 3, total missed: 10
# Query score: [0 0 0 0 0], rank of 1st relevant case: 0, mrr_w_penalty: 7.588, mrr: 21.083, number of cases still missing in the query 3, total missed: 3
# Query score: [0 0 1 1 1], rank of 1st relevant case: 3, mrr_w_penalty: 7.788, mrr: 21.417, number of cases still missing in the query 2, total missed: 9
# Query score: [0 0 0 0 0], rank of 1st relevant case: 0, mrr_w_penalty: 7.788, mrr: 21.417, number of cases still missing in the query 3, total missed: 3
# Query score: [0 0 0 0 0], rank of 1st relevant case: 0, mrr_w_penalty: 7.788, mrr: 21.417, number of cases still missing in the query 1, total missed: 1
# Query score: [0 0 0 0 0], rank of 1st relevant case: 0, mrr_w_penalty: 7.788, mrr: 21.417, number of cases still missing in the query 0, total missed: 0
# Query score: [0 0 0 0 0], rank of 1st relevant case: 0, mrr_w_penalty: 7.788, mrr: 21.417, number of cases still missing in the query 1, total missed: 1
# Query score: [1 0 0 0 0], rank of 1st relevant case: 1, mrr_w_penalty: 8.038, mrr: 22.417, number of cases still missing in the query 3, total missed: 3
# Query score: [0 0 0 0 0], rank of 1st relevant case: 0, mrr_w_penalty: 8.038, mrr: 22.417, number of cases still missing in the query 2, total missed: 2
# Query score: [0 0 1 1 1], rank of 1st relevant case: 3, mrr_w_penalty: 8.238, mrr: 22.750, number of cases still missing in the query 2, total missed: 9
# Query score: [1 0 0 0 0], rank of 1st relevant case: 1, mrr_w_penalty: 8.738, mrr: 23.750, number of cases still missing in the query 1, total missed: 1
# Query score: [0 0 1 0 0], rank of 1st relevant case: 3, mrr_w_penalty: 8.905, mrr: 24.083, number of cases still missing in the query 3, total missed: 3
# Query score: [1 0 0 0 0], rank of 1st relevant case: 1, mrr_w_penalty: 9.105, mrr: 25.083, number of cases still missing in the query 4, total missed: 4
# Query score: [0 0 0 0 0], rank of 1st relevant case: 0, mrr_w_penalty: 9.105, mrr: 25.083, number of cases still missing in the query 0, total missed: 0
# Query score: [0 0 0 0 0], rank of 1st relevant case: 0, mrr_w_penalty: 9.105, mrr: 25.083, number of cases still missing in the query 0, total missed: 0
# Query score: [0 0 0 1 0], rank of 1st relevant case: 4, mrr_w_penalty: 9.248, mrr: 25.333, number of cases still missing in the query 3, total missed: 3
# Query score: [1 1 1 0 0], rank of 1st relevant case: 1, mrr_w_penalty: 9.581, mrr: 26.333, number of cases still missing in the query 2, total missed: 6
# Query score: [0 0 0 0 0], rank of 1st relevant case: 0, mrr_w_penalty: 9.581, mrr: 26.333, number of cases still missing in the query 0, total missed: 0
# Query score: [1 1 1 0 0], rank of 1st relevant case: 1, mrr_w_penalty: 9.914, mrr: 27.333, number of cases still missing in the query 2, total missed: 6

# %%
import matplotlib.pyplot as plt
import seaborn as sns

figure_title_names = {
    "cosine_search_euProvisions": "Cosine similarity of cases using shared\nEU Legislation",
    "cosine_search_eurovoc": "Cosine similarity of cases using shared\nEuroVoc Labels",
    "cosine_search_both": "Cosine similarity of cases using both shared\nEU Legislation and EuroVoc Labels",
    "cosine_search_citation": "Cosine similarity of cases using citations of EU instruments"
}

plt.figure(figsize = (16,9))
sns.set_theme(style = "whitegrid")
for func_name, score_func in scores_search_function.items():
    scores_df = pd.DataFrame(score_func)
    # scores_df = scores_df[scores_df["Model"] == "paraphrase-multilingual-mpnet-base-v2"]

    fig = sns.catplot(kind = "bar", data = scores_df, x = "Score", y = "Value", hue = "Pair", col = "Model")
    fig.figure.subplots_adjust(top=0.85)
    fig.figure.suptitle(figure_title_names[func_name])
    
    plt.savefig(f"{func_name}.png", transparent = False)
    plt.show()

# %%
# import numpy as np

# from sklearn.metrics.pairwise import cosine_similarity

# # at least one shared EU provision ==> similar
# # at least one shared EuroVoc ==> similar
# # eval - score each of the 5 retrieved cases for shared celex codes (only one celex now)

# def cosine_search_both(query, search, top_k):
#     cosine_scores = cosine_similarity(query, search)
#     score_doc = []

#     for i in range(cosine_scores.shape[0]):
#         all_matches = np.argsort(cosine_scores[i])[::-1]
#         best_matches = all_matches[1:top_k+1]

#         query_celex = df.iloc[i]["euProvisions"][0]["celex"]
#         query_eurovec = df.iloc[i]["eurovoc"][0]["label"]

#         # see which top_k retrieved documents were retrieved
#         score = []
#         for retrieved_case in best_matches:
#             retrieved_celex = [provision["celex"] for provision in df.iloc[retrieved_case]["euProvisions"]]
#             retrieved_eurovec = [provision["label"] for provision in df.iloc[retrieved_case]["eurovoc"]]
#             score.append(int(query_celex in retrieved_celex or query_eurovec in retrieved_eurovec))

#         ### find all relevant cases that were missed
#         missed_matches = []
#         for retrieved_case in all_matches[1:]:
#             retrieved_celex = [provision["celex"] for provision in df.iloc[retrieved_case]["euProvisions"]]
#             retrieved_eurovec = [provision["label"] for provision in df.iloc[retrieved_case]["eurovoc"]]
#             missed_matches.append(int(query_celex in retrieved_celex or query_eurovec in retrieved_eurovec))
        
#         no_missed_matches = np.sum(missed_matches) if np.sum(missed_matches) > 0 else 1
#         score_doc.append([np.sum(score)/top_k, np.sum(score)/no_missed_matches])
        
#     # macro precision and recall
#     precision, recall = np.mean(score_doc, 0)
#     f1 = 2 * precision * recall / (precision + recall)

#     return precision, recall, f1

# %% [markdown]
# Further refinement: check the retrieved documents, and if they are not relevant continue searching until a relevant case is found, up until top_k documents have been found

# %%
# arr_sc = []
# mean_sc = []
# for sc in s:
#     arr_sc.append(sc["cosine_search_euProvisions"]["Value"])


# arr_sc = np.asarray(arr_sc)
# for idx in range(arr_sc.shape[1]):
#     mean_sc.append(np.mean(arr_sc[:, idx]))

# scores = {"Model": [], "Pair": [], "Value": [], "Score": []}
# mean_sc
# sc_new = {"Model": s[0]["cosine_search_euProvisions"]["Model"], "Pair": s[0]["cosine_search_euProvisions"]["Pair"], "Value": mean_sc, "Score": s[0]["cosine_search_euProvisions"]["Score"]}
# # sc_new = {"func_name": {"cosine_search_euProvisions": sc_new}}

# sc_new

# %%
# # optimal_top_k = 25 (debatable) 

# from collections import defaultdict
# from functools import partial
# from tqdm import tqdm

# models = ["distiluse-base-multilingual-cased-v2", "paraphrase-multilingual-mpnet-base-v2"]
# # search_functions = [partial(cosine_search, query_type = "euProvisions"), partial(cosine_search, query_type = "eurovoc"), cosine_search_both]
# search_functions = [partial(cosine_search, query_type = "euProvisions")]

# used_data = "non_temp"
# metrics = ["Precision", "Recall", "F1", "MRR"]

# sl, tl = "EN", "IT"

# s = []

# for group in groups_non_temp:
#     scores_search_function = defaultdict()
#     for search_func in tqdm(search_functions):
#         scores = {"Model": [], "Pair": [], "Value": [], "Score": []}

#         for model_name in models:
#             model = SentenceTransformer("models/" + model_name).to(device)

#             data_pairs = [
#                 (f"{sl}-{sl}", np.asarray(group["summaryEn"].apply(model.encode).tolist()), np.asarray(group["summaryEn"].apply(model.encode).tolist())),
#                 (f"{tl}-{tl}", np.asarray(group["summary"].apply(model.encode).tolist()), np.asarray(group["summary"].apply(model.encode).tolist())),
#                 (f"{sl}-{tl}", np.asarray(group["summaryEn"].apply(model.encode).tolist()), np.asarray(group["summary"].apply(model.encode).tolist())),
#                 (f"{tl}-{sl}", np.asarray(group["summary"].apply(model.encode).tolist()), np.asarray(group["summaryEn"].apply(model.encode).tolist()))
#             ]

#             for (pair, query, search) in data_pairs:
#                 precision, recall, f1, mrr = search_func(query = query, search = search, top_k = 5)

#                 scores["Model"] += [model_name] * len(metrics)
#                 scores["Pair"] += [pair] * len(metrics)
#                 scores["Value"] += [precision, recall, f1]
#                 scores["Score"] += [metrics]

#         name = ""
#         if type(search_func) == partial:
#             name = search_func.func.__name__ + "_" + "_".join(list(search_func.keywords.values()))
#         else:
#             name = search_func.__name__
#         scores_search_function[name] = scores

#     s.append(scores_search_function)

# %%
# import matplotlib.pyplot as plt
# import seaborn as sns

# figure_title_names = {
#     "cosine_search_euProvisions": "Cosine similarity of cases using shared\nEU Legislation",
#     "cosine_search_eurovoc": "Cosine similarity of cases using shared\nEuroVoc Labels",
#     "cosine_search_both": "Cosine similarity of cases using both shared\nEU Legislation and EuroVoc Labels"
# }

# plt.figure(figsize = (16,9))
# sns.set_theme(style = "whitegrid")
# scores_df = pd.DataFrame(sc_new)
# print(scores_df)
# # scores_df = scores_df[scores_df["Model"] == "paraphrase-multilingual-mpnet-base-v2"]

# fig = sns.catplot(kind = "bar", data = scores_df, x = "Score", y = "Value", hue = "Pair", col = "Model")
# fig.figure.subplots_adjust(top=0.85)
# fig.figure.suptitle("cosine_search_euProvisions")

# plt.savefig(f"cosine_search_euProvisions_{used_data}.png", transparent = False)
# plt.show()
